# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
import numpy as np

# %%
pulled_artists = pd.read_csv('../data/final_merged.csv')
new_artists = pd.read_csv('../data/edm_artists.csv')
pulled_artist_list = list(set(pulled_artists['artist']))
new_artists_list = list(set(new_artists['A-Trak']))

# %%
for i in new_artists_list:
    if i in pulled_artist_list:
        new_artists_list.remove(i)

# %%
len(new_artists_list)
# Out:
# 118

# %%
client_id= 
client_secret=

# %%
client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id, 
    client_secret=client_secret
)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

name = new_artists_list

# %%
#Seaches for input artist. Returns  full json for artist search
result = []
result_count = 0
sleep_min = 3
sleep_max = 6
start_time = time.time()
for i in name:
    result.append(sp.search(i))
    result_count += 1
    if result_count % 25 == 0:
            time.sleep(np.random.uniform(sleep_min, sleep_max))

# %%
len(result)
# Out:
# 130

# %%
uris = []
uri_count = 0
for i in result:
    try:
        uris.append(i['tracks']['items'][1]['artists'])
        uri_count += 1
    except:
        pass
print(f'Total URIs: {uri_count}')
# Out:
# Total URIs: 129

# %%
#gets seachable artist uri for album 
artists_uris = []
for i in uris:
    for ob in i:
        artists_uris.append(ob.get('id'))
#searches artists albums by uri and returns another json
artist_albums = []
artist_album_count = 0
for i in artists_uris:
    artist_album_count += 1
    artist_albums.append(sp.artist_albums(i, album_type='album'))
    if artist_album_count % 50 == 0:
            time.sleep(np.random.uniform(sleep_min, sleep_max))
            print(artist_album_count)

artist_album_names = []
artist_album_uris = []
artist_albums
for i in artist_albums:
    for object in range(len(i['items'])):
        artist_album_names.append(i['items'][object]['name'])
        artist_album_uris.append(i['items'][object]['uri'])
# Out:
# 50
# 100
# 150
# 200
# 250

# %%
len(artist_albums)
# Out:
# 259

# %%
album_uri_list = [s.replace("spotify:album:", "") for s in artist_album_uris]

# %%
res = []
for i in album_uri_list:
    if i not in res:
        res.append(i)
len(res)
# Out:
# 1634

# %%
def album_songs(uri):
    album = uri 
    spotify_albums[album] = {}
   
    spotify_albums[album]['album'] = [] 
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []

    tracks = sp.album_tracks(album)
     
    for n in range(len(tracks['items'])): 
        spotify_albums[album]['album'].append(artist_album_names[album_count]) 
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
spotify_albums = {}
album_count = 0

for i in res:
    album_songs(i)
    album_count += 1
    if album_count % 50 == 0:
            time.sleep(np.random.uniform(sleep_min, sleep_max))
    if album_count % 500 == 0:
            print(f'({(album_count/500) * 500} Albums now in Library')
print(f'Total albums: {album_count}')
# Out:
# (500.0 Albums now in Library
# (1000.0 Albums now in Library
# (1500.0 Albums now in Library
# Total albums: 1634

# %%
song_id = []
for i in spotify_albums:
    for track in spotify_albums[i]['uri']:
        song_id.append(track)

# %%
with open('listfile.txt', 'w') as filehandle:
    for listitem in song_id:
        filehandle.write('%s\n' % listitem)

# %%
song_id = []

# open file and read the content in a list
with open('listfile.txt', 'r') as filehandle:
    for line in filehandle:
        
        currentsong = line[:-1]
        song_id.append(currentsong)

# %%
len(song_id[23032:])
# Out:
# 3005

# %%
sleep_min = 2
sleep_max = 5
features = []
pop = []
request_count = 0
for i in song_id[23032:]:
    features.append(sp.audio_features(i))
    pop.append(sp.track(i))
    request_count += 1
    if request_count % 50 == 0:
        print('working on it')
        time.sleep(np.random.uniform(sleep_min, sleep_max))
    if request_count % 1000 == 0:
        time.sleep(sleep_max)
        print('taking a short break')
    if request_count % 2000 == 0:
        print(f'{int(request_count)} Songs now in Library')
    if request_count > 30000:
        print('stopping')
        break
# Out:
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# taking a short break
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# taking a short break
# 2000 Songs now in Library
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# taking a short break

# %%
features_dict = []
for i in features:
    for d in i:
       features_dict.append(d)
features_dict = [i for i in features_dict if i is not None]

# %%
popular_df = pd.DataFrame(pop)
feat_df = pd.DataFrame(features_dict)

# %%
popular_df.to_csv('edm8_popularity.csv')
feat_df.to_csv('edm8_track_features.csv')

# %%
popular_df
# Out:
#                                                   album  \
# 0     {'album_type': 'album', 'artists': [{'external...
# 1     {'album_type': 'album', 'artists': [{'external...
# 2     {'album_type': 'album', 'artists': [{'external...
# 3     {'album_type': 'album', 'artists': [{'external...
# 4     {'album_type': 'album', 'artists': [{'external...
# ...                                                 ...
# 3650  {'album_type': 'album', 'artists': [{'external...
# 3651  {'album_type': 'album', 'artists': [{'external...
# 3652  {'album_type': 'album', 'artists': [{'external...
# 3653  {'album_type': 'album', 'artists': [{'external...
# 3654  {'album_type': 'album', 'artists': [{'external...
#
#                                                 artists  \
# 0     [{'external_urls': {'spotify': 'https://open.s...
# 1     [{'external_urls': {'spotify': 'https://open.s...
# 2     [{'external_urls': {'spotify': 'https://open.s...
# 3     [{'external_urls': {'spotify': 'https://open.s...
# 4     [{'external_urls': {'spotify': 'https://open.s...
# ...                                                 ...
# 3650  [{'external_urls': {'spotify': 'https://open.s...
# 3651  [{'external_urls': {'spotify': 'https://open.s...
# 3652  [{'external_urls': {'spotify': 'https://open.s...
# 3653  [{'external_urls': {'spotify': 'https://open.s...
# 3654  [{'external_urls': {'spotify': 'https://open.s...
#
#                                       available_markets  disc_number  \
# 0     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4     [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# ...                                                 ...          ...
# 3650  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3651  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3652  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3653  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3654  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#       duration_ms  explicit              external_ids  \
# 0          306333     False  {'isrc': 'USSM10310153'}
# 1          237906     False  {'isrc': 'USSM10310154'}
# 2          228906     False  {'isrc': 'USSM10310155'}
# 3          332826     False  {'isrc': 'USSM10310156'}
# 4          485226     False  {'isrc': 'USSM10212984'}
# ...           ...       ...                       ...
# 3650       199880     False  {'isrc': 'GBUM71605368'}
# 3651       151293     False  {'isrc': 'GBUM71605361'}
# 3652       169840     False  {'isrc': 'GBUM71605359'}
# 3653       270946     False  {'isrc': 'GBUM71605364'}
# 3654       290253     False  {'isrc': 'GBUM71605377'}
#
#                                           external_urls  \
# 0     {'spotify': 'https://open.spotify.com/track/2e...
# 1     {'spotify': 'https://open.spotify.com/track/5F...
# 2     {'spotify': 'https://open.spotify.com/track/3N...
# 3     {'spotify': 'https://open.spotify.com/track/2J...
# 4     {'spotify': 'https://open.spotify.com/track/0U...
# ...                                                 ...
# 3650  {'spotify': 'https://open.spotify.com/track/5K...
# 3651  {'spotify': 'https://open.spotify.com/track/4n...
# 3652  {'spotify': 'https://open.spotify.com/track/6l...
# 3653  {'spotify': 'https://open.spotify.com/track/4m...
# 3654  {'spotify': 'https://open.spotify.com/track/0P...
#
#                                                    href  \
# 0     https://api.spotify.com/v1/tracks/2eMVogxm08Lg...
# 1     https://api.spotify.com/v1/tracks/5FPnjikbwlDM...
# 2     https://api.spotify.com/v1/tracks/3Ngl8Fn5UtCl...
# 3     https://api.spotify.com/v1/tracks/2Jr39bnXx3WO...
# 4     https://api.spotify.com/v1/tracks/0UVXkzxIKO5e...
# ...                                                 ...
# 3650  https://api.spotify.com/v1/tracks/5KBcHMsC4SQ2...
# 3651  https://api.spotify.com/v1/tracks/4noFnLoVDkw5...
# 3652  https://api.spotify.com/v1/tracks/6lSCOKoXAFgP...
# 3653  https://api.spotify.com/v1/tracks/4mLnTqoPdY6f...
# 3654  https://api.spotify.com/v1/tracks/0P3rhnslByO8...
#
#                           id  is_local  \
# 0     2eMVogxm08LgfgnWpahooV     False
# 1     5FPnjikbwlDMULCCCa6ZCJ     False
# 2     3Ngl8Fn5UtCl2K7UD7EF9e     False
# 3     2Jr39bnXx3WOUmdlI4S00f     False
# 4     0UVXkzxIKO5e4VXXM4ErjJ     False
# ...                      ...       ...
# 3650  5KBcHMsC4SQ2NiATcZPzmf     False
# 3651  4noFnLoVDkw5oK7xNGMzOh     False
# 3652  6lSCOKoXAFgPlmMrWJ74bJ     False
# 3653  4mLnTqoPdY6fFHaOf609XI     False
# 3654  0P3rhnslByO8sdibePceui     False
#
#                                                    name  popularity  \
# 0                                  Split Screen Sadness          53
# 1                                             Daughters          68
# 2                                            Only Heart          44
# 3                                                 Wheel          46
# 4     3x5 - Live at the Oak Mountain Amphitheater, B...          33
# ...                                                 ...         ...
# 3650                                       Lola's Theme          41
# 3651                                           Children          39
# 3652                                  9pm (Till I Come)          45
# 3653                                                 Go          35
# 3654                                          Your Love          35
#
#                                             preview_url  track_number   type  \
# 0     https://p.scdn.co/mp3-preview/94bcbd4dd46134e6...             7  track
# 1     https://p.scdn.co/mp3-preview/9fc190efe8f2fb49...             8  track
# 2     https://p.scdn.co/mp3-preview/01bf8c39d7420a4e...             9  track
# 3     https://p.scdn.co/mp3-preview/09e2ad36a37a3d0c...            10  track
# 4     https://p.scdn.co/mp3-preview/530785338598de37...             1  track
# ...                                                 ...           ...    ...
# 3650                                               None             4  track
# 3651                                               None             5  track
# 3652                                               None             6  track
# 3653                                               None             7  track
# 3654                                               None             8  track
#
#                                        uri
# 0     spotify:track:2eMVogxm08LgfgnWpahooV
# 1     spotify:track:5FPnjikbwlDMULCCCa6ZCJ
# 2     spotify:track:3Ngl8Fn5UtCl2K7UD7EF9e
# 3     spotify:track:2Jr39bnXx3WOUmdlI4S00f
# 4     spotify:track:0UVXkzxIKO5e4VXXM4ErjJ
# ...                                    ...
# 3650  spotify:track:5KBcHMsC4SQ2NiATcZPzmf
# 3651  spotify:track:4noFnLoVDkw5oK7xNGMzOh
# 3652  spotify:track:6lSCOKoXAFgPlmMrWJ74bJ
# 3653  spotify:track:4mLnTqoPdY6fFHaOf609XI
# 3654  spotify:track:0P3rhnslByO8sdibePceui
#
# [3655 rows x 17 columns]

# %%
feat_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.635   0.789    7    -3.969     1       0.0240      0.024900
# 1            0.674   0.413    2    -7.816     1       0.0274      0.836000
# 2            0.665   0.841    5    -2.619     1       0.0340      0.037700
# 3            0.582   0.395   10    -8.279     1       0.0274      0.551000
# 4            0.269   0.734    5    -9.558     0       0.0365      0.148000
# ...            ...     ...  ...       ...   ...          ...           ...
# 3650         0.630   0.502    0    -8.463     1       0.0489      0.011400
# 3651         0.700   0.662    9    -6.814     0       0.0326      0.054200
# 3652         0.497   0.916    4    -8.025     0       0.0413      0.000242
# 3653         0.560   0.910    4    -6.759     0       0.0350      0.085900
# 3654         0.693   0.903    6    -4.423     0       0.0385      0.003600
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000017    0.1490   0.3310  107.989  audio_features
# 1             0.000019    0.0980   0.5030  124.893  audio_features
# 2             0.000336    0.1030   0.9510  120.946  audio_features
# 3             0.000115    0.2580   0.2260  117.178  audio_features
# 4             0.003360    0.9260   0.3590   99.268  audio_features
# ...                ...       ...      ...      ...             ...
# 3650          0.032300    0.1080   0.0656  135.002  audio_features
# 3651          0.305000    0.3630   0.2080  135.012  audio_features
# 3652          0.940000    0.1270   0.1030  126.019  audio_features
# 3653          0.518000    0.1010   0.3240  117.991  audio_features
# 3654          0.000233    0.0304   0.6490  125.028  audio_features
#
#                           id                                   uri  \
# 0     2eMVogxm08LgfgnWpahooV  spotify:track:2eMVogxm08LgfgnWpahooV
# 1     5FPnjikbwlDMULCCCa6ZCJ  spotify:track:5FPnjikbwlDMULCCCa6ZCJ
# 2     3Ngl8Fn5UtCl2K7UD7EF9e  spotify:track:3Ngl8Fn5UtCl2K7UD7EF9e
# 3     2Jr39bnXx3WOUmdlI4S00f  spotify:track:2Jr39bnXx3WOUmdlI4S00f
# 4     0UVXkzxIKO5e4VXXM4ErjJ  spotify:track:0UVXkzxIKO5e4VXXM4ErjJ
# ...                      ...                                   ...
# 3650  4noFnLoVDkw5oK7xNGMzOh  spotify:track:4noFnLoVDkw5oK7xNGMzOh
# 3651  6lSCOKoXAFgPlmMrWJ74bJ  spotify:track:6lSCOKoXAFgPlmMrWJ74bJ
# 3652  4mLnTqoPdY6fFHaOf609XI  spotify:track:4mLnTqoPdY6fFHaOf609XI
# 3653  0P3rhnslByO8sdibePceui  spotify:track:0P3rhnslByO8sdibePceui
# 3654  3w5tSTIW0CDQtdnYfB6tUs  spotify:track:3w5tSTIW0CDQtdnYfB6tUs
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2eMVogxm08Lg...
# 1     https://api.spotify.com/v1/tracks/5FPnjikbwlDM...
# 2     https://api.spotify.com/v1/tracks/3Ngl8Fn5UtCl...
# 3     https://api.spotify.com/v1/tracks/2Jr39bnXx3WO...
# 4     https://api.spotify.com/v1/tracks/0UVXkzxIKO5e...
# ...                                                 ...
# 3650  https://api.spotify.com/v1/tracks/4noFnLoVDkw5...
# 3651  https://api.spotify.com/v1/tracks/6lSCOKoXAFgP...
# 3652  https://api.spotify.com/v1/tracks/4mLnTqoPdY6f...
# 3653  https://api.spotify.com/v1/tracks/0P3rhnslByO8...
# 3654  https://api.spotify.com/v1/tracks/3w5tSTIW0CDQ...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2eMV...       306333
# 1     https://api.spotify.com/v1/audio-analysis/5FPn...       237907
# 2     https://api.spotify.com/v1/audio-analysis/3Ngl...       228907
# 3     https://api.spotify.com/v1/audio-analysis/2Jr3...       332827
# 4     https://api.spotify.com/v1/audio-analysis/0UVX...       485227
# ...                                                 ...          ...
# 3650  https://api.spotify.com/v1/audio-analysis/4noF...       151293
# 3651  https://api.spotify.com/v1/audio-analysis/6lSC...       169840
# 3652  https://api.spotify.com/v1/audio-analysis/4mLn...       270947
# 3653  https://api.spotify.com/v1/audio-analysis/0P3r...       290253
# 3654  https://api.spotify.com/v1/audio-analysis/3w5t...       283120
#
#       time_signature
# 0                  4
# 1                  3
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3650               4
# 3651               4
# 3652               4
# 3653               4
# 3654               4
#
# [3655 rows x 18 columns]
