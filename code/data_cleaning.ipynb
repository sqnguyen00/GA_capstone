# %%
import pandas as pd
import ast
import os

# %%
all_files =  os.listdir('../data/')
popular = [f for f in all_files if (f.lower().endswith("popularity.csv"))]
song_feat = [f for f in all_files if (f.lower().endswith("features.csv"))]

# %%
pop_dfs = list()
sf_dfs = list()
for filename in popular:
     dfs = pd.read_csv(f'../data/{filename}')
     pop_dfs.append(dfs)
pop = pd.concat(pop_dfs)

for filename in song_feat:
     sfdfs = pd.read_csv(f'../data/{filename}')
     sf_dfs.append(sfdfs)
feat = pd.concat(sf_dfs)

# %%
pop.head()
# Out:
#    Unnamed: 0                                              album  \
# 0           0  {'album_type': 'album', 'artists': [{'external...
# 1           1  {'album_type': 'album', 'artists': [{'external...
# 2           2  {'album_type': 'album', 'artists': [{'external...
# 3           3  {'album_type': 'album', 'artists': [{'external...
# 4           4  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 1  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 2  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 3  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 4  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
#
#    duration_ms  explicit              external_ids  \
# 0       230813      True  {'isrc': 'GBARL1700262'}
# 1       235973      True  {'isrc': 'GBARL1700768'}
# 2       229160      True  {'isrc': 'GBARL1700589'}
# 3       272653      True  {'isrc': 'GBARL1700769'}
# 4       204280      True  {'isrc': 'GBARL1700766'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/7t...
# 1  {'spotify': 'https://open.spotify.com/track/0W...
# 2  {'spotify': 'https://open.spotify.com/track/60...
# 3  {'spotify': 'https://open.spotify.com/track/0l...
# 4  {'spotify': 'https://open.spotify.com/track/4K...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/7tr2za8SQg2C...  7tr2za8SQg2CI8EDgrdtNl
# 1  https://api.spotify.com/v1/tracks/0Ws8D3EWUDgY...  0Ws8D3EWUDgY962Xftb0h5
# 2  https://api.spotify.com/v1/tracks/60APt5N2NRaK...  60APt5N2NRaKWf5xzJdzyC
# 3  https://api.spotify.com/v1/tracks/0lMbuWUpfTWh...  0lMbuWUpfTWhEmOKxppEau
# 4  https://api.spotify.com/v1/tracks/4KaIJ1FWXUoA...  4KaIJ1FWXUoAAnOts1YWjD
#
#    is_local                                               name  popularity  \
# 0     False                  Slide (feat. Frank Ocean & Migos)          69
# 1     False  Cash Out (feat. ScHoolboy Q, PARTYNEXTDOOR & D...          56
# 2     False  Heatstroke (feat. Young Thug, Pharrell William...          58
# 3     False                     Rollin (feat. Future & Khalid)          64
# 4     False           Prayers Up (feat. Travis Scott & A-Trak)          56
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/d3e8d7ced6e0f384...             1  track
# 1  https://p.scdn.co/mp3-preview/6dc54b40c3664b8b...             2  track
# 2  https://p.scdn.co/mp3-preview/a43b6717d8333767...             3  track
# 3  https://p.scdn.co/mp3-preview/78fad076a030a8b3...             4  track
# 4  https://p.scdn.co/mp3-preview/10607f537b1f93c3...             5  track
#
#                                     uri
# 0  spotify:track:7tr2za8SQg2CI8EDgrdtNl
# 1  spotify:track:0Ws8D3EWUDgY962Xftb0h5
# 2  spotify:track:60APt5N2NRaKWf5xzJdzyC
# 3  spotify:track:0lMbuWUpfTWhEmOKxppEau
# 4  spotify:track:4KaIJ1FWXUoAAnOts1YWjD

# %%
feat.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.531   0.816   10    -4.240     0       0.1020
# 1           1         0.687   0.758    5    -5.285     0       0.0564
# 2           2         0.746   0.944    8    -5.525     0       0.2460
# 3           3         0.433   0.668    6    -7.694     1       0.0443
# 4           4         0.635   0.844    4    -6.086     1       0.0970
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0       0.42100          0.000321     0.475    0.310  153.974  audio_features
# 1       0.10900          0.000070     0.185    0.441   91.911  audio_features
# 2       0.00208          0.341000     0.169    0.533  140.108  audio_features
# 3       0.00947          0.000000     0.113    0.324  100.008  audio_features
# 4       0.13700          0.331000     0.379    0.220   75.031  audio_features
#
#                        id                                   uri  \
# 0  3egj44N2tiuW5F2MrqmBjW  spotify:track:3egj44N2tiuW5F2MrqmBjW
# 1  1WAWbKpQe3XMp4b96bjazD  spotify:track:1WAWbKpQe3XMp4b96bjazD
# 2  1HFIgvDlSCjC95Ch6h6gF7  spotify:track:1HFIgvDlSCjC95Ch6h6gF7
# 3  0mEYJIIBcUt2GH4ftYKJ5Q  spotify:track:0mEYJIIBcUt2GH4ftYKJ5Q
# 4  0vQ5VW753vuqUdi4mipjVl  spotify:track:0vQ5VW753vuqUdi4mipjVl
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3egj44N2tiuW...
# 1  https://api.spotify.com/v1/tracks/1WAWbKpQe3XM...
# 2  https://api.spotify.com/v1/tracks/1HFIgvDlSCjC...
# 3  https://api.spotify.com/v1/tracks/0mEYJIIBcUt2...
# 4  https://api.spotify.com/v1/tracks/0vQ5VW753vuq...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3egj...       180779
# 1  https://api.spotify.com/v1/audio-analysis/1WAW...       205000
# 2  https://api.spotify.com/v1/audio-analysis/1HFI...       195097
# 3  https://api.spotify.com/v1/audio-analysis/0mEY...       223765
# 4  https://api.spotify.com/v1/audio-analysis/0vQ5...       219200
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
pop['album'][0]
# Out:
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# Name: album, dtype: object

# %%
pop['artists'][0]
# Out:
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# Name: artists, dtype: object

# %%
dates_list = []
album = []
artist = []
for i in pop['album']:
    temp = ast.literal_eval(i)
    dates_list.append(temp.get('release_date'))
    album.append(temp.get('name'))

for i in pop['artists']:
    res = i.strip('][').split(', ')
    res[3] = res[3].replace("'name': ", "")
    artist.append(res[3].replace("'", ''))


pop['release_date']=dates_list
pop['album'] = album
pop['artist'] = artist

# %%
feat.shape
# Out:
# (58983, 19)

# %%
pop.shape
# Out:
# (59049, 20)

# %%
pop['artist'].value_counts()
# Out:
# Chris Brown       1156
# Drake             1065
# Kendrick Lamar     992
# Ariana Grande      924
# ATB                874
#                   ...
# M.I.K.E.             1
# Matt Bowdidge        1
# Conjure One          1
# Sleepthief           1
# Cenk Basaran         1
# Name: artist, Length: 2157, dtype: int64

# %%
final = pd.merge(feat, pop, on='id', how ='left')

# %%
final.shape
# Out:
# (82265, 38)

# %%
features = ['release_date', 'artist', 'name', 'album', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms_y', 'id']
final = final[features]

# %%
final.shape
# Out:
# (82265, 18)

# %%
final.drop_duplicates(subset = ['name', 'artist'], inplace = True)
final
# Out:
#       release_date         artist  \
# 0       2018-02-23        L D R U
# 1       2018-02-23        L D R U
# 2       2018-02-23        L D R U
# 3       2018-02-23        L D R U
# 4       2018-02-23        L D R U
# ...            ...            ...
# 82260   2003-08-19  Kings of Leon
# 82261   2003-08-19  Kings of Leon
# 82262   2003-08-19  Kings of Leon
# 82263   2003-08-19  Kings of Leon
# 82264   2003-08-19  Kings of Leon
#
#                                                name                    album  \
# 0             The Calling - ORIENTAL CRAVINGS Remix        Sizzlar (Remixes)
# 1      Keeping Score (feat. Paige IV) - Paces Remix        Sizzlar (Remixes)
# 2             Take My (feat. Rob Taylor) - UZ Remix        Sizzlar (Remixes)
# 3      Next to You (feat. Savoi) - Yomi Twice Remix        Sizzlar (Remixes)
# 4                        Pop That - Sub-human Remix        Sizzlar (Remixes)
# ...                                             ...                      ...
# 82260                              Molly's Chambers  Youth And Young Manhood
# 82261                                        Genius  Youth And Young Manhood
# 82262                                         Dusty  Youth And Young Manhood
# 82263                         Holy Roller Novocaine  Youth And Young Manhood
# 82264                                  Talihina Sky  Youth And Young Manhood
#
#        popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0               8         0.531   0.816   10    -4.240     0       0.1020
# 1              16         0.687   0.758    5    -5.285     0       0.0564
# 2              11         0.746   0.944    8    -5.525     0       0.2460
# 3               7         0.433   0.668    6    -7.694     1       0.0443
# 4               7         0.635   0.844    4    -6.086     1       0.0970
# ...           ...           ...     ...  ...       ...   ...          ...
# 82260          63         0.598   0.911   11    -3.970     1       0.0515
# 82261          41         0.442   0.830    7    -5.978     1       0.0478
# 82262          39         0.661   0.519    9    -7.192     1       0.0297
# 82263          49         0.571   0.735   11    -5.632     0       0.0743
# 82264          41         0.642   0.522   11    -5.654     0       0.0261
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0           0.42100          0.000321    0.4750    0.310  153.974
# 1           0.10900          0.000070    0.1850    0.441   91.911
# 2           0.00208          0.341000    0.1690    0.533  140.108
# 3           0.00947          0.000000    0.1130    0.324  100.008
# 4           0.13700          0.331000    0.3790    0.220   75.031
# ...             ...               ...       ...      ...      ...
# 82260       0.22200          0.000004    0.2160    0.953  146.469
# 82261       0.02750          0.000000    0.2180    0.506  125.554
# 82262       0.16200          0.000000    0.0846    0.313  105.034
# 82263       0.03290          0.000264    0.2150    0.557  106.811
# 82264       0.24300          0.000000    0.0915    0.391  114.431
#
#        duration_ms_y                      id
# 0             180779  3egj44N2tiuW5F2MrqmBjW
# 1             205000  1WAWbKpQe3XMp4b96bjazD
# 2             195097  1HFIgvDlSCjC95Ch6h6gF7
# 3             223764  0mEYJIIBcUt2GH4ftYKJ5Q
# 4             219200  0vQ5VW753vuqUdi4mipjVl
# ...              ...                     ...
# 82260         134906  0nCAVzknkzRXRgB6LhRv04
# 82261         168840  3iUUve7vVMnS4zHLWpv3mh
# 82262         260399  3iYPdrNM4hzxfhmMhb3UoT
# 82263         243000  5fv9AxkRVzCwT5XkpYjWvL
# 82264         227440  7GWViYkd4fTS3ApKuaTLEB
#
# [30231 rows x 18 columns]

# %%
final.to_csv('../data/final_merged.csv')
