# %%
import pandas as pd
import ast
import os

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time
import numpy as np

# %%
client_id= 
client_secret= 

client_credentials_manager = SpotifyClientCredentials(
    client_id=client_id, 
    client_secret=client_secret
)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
all_files =  os.listdir('../data/')
popular = [f for f in all_files if (f.lower().endswith("popularity.csv"))]
song_feat = [f for f in all_files if (f.lower().endswith("features.csv"))]

# %%
pop_dfs = list()
sf_dfs = list()
for filename in popular:
     dfs = pd.read_csv(f'../data/{filename}')
     pop_dfs.append(dfs)
pop = pd.concat(pop_dfs)

for filename in song_feat:
     sfdfs = pd.read_csv(f'../data/{filename}')
     sf_dfs.append(sfdfs)
feat = pd.concat(sf_dfs)

# %%
features = ['id', 'popularity', 'name']

# %%
dates_list = []
album = []
artist = []
for i in pop['album']:
    temp = ast.literal_eval(i)
    dates_list.append(temp.get('release_date'))
    album.append(temp.get('name'))

for i in pop['artists']:
    res = i.strip('][').split(', ')
    res[3] = res[3].replace("'name': ", "")
    artist.append(res[3].replace("'", ''))


pop['release_date']=dates_list
pop['album'] = album
pop['artist'] = artist

# %%
pulled_artist_list = list(set(feat['id']))
new_artists_list = list(set(pop['id']))

# %%
len(new_artists_list)
# Out:
# 41910

# %%
feat.shape
# Out:
# (47925, 19)

# %%
pop[features].shape
# Out:
# (48385, 3)

# %%
merged_df =  pd.merge(feat, pop, on='id', how ='left')

# %%
merged_df
# Out:
#        Unnamed: 0_x  danceability  energy  key  loudness  mode  speechiness  \
# 0                 0         0.531   0.816   10    -4.240     0       0.1020
# 1                 1         0.687   0.758    5    -5.285     0       0.0564
# 2                 2         0.746   0.944    8    -5.525     0       0.2460
# 3                 3         0.433   0.668    6    -7.694     1       0.0443
# 4                 4         0.635   0.844    4    -6.086     1       0.0970
# ...             ...           ...     ...  ...       ...   ...          ...
# 61436          3998         0.663   0.802    1    -7.649     0       0.0566
# 61437          3999         0.740   0.775    9    -7.067     0       0.0567
# 61438          4000         0.761   0.747    1    -8.217     1       0.0475
# 61439          4001         0.806   0.785    0    -6.079     1       0.0469
# 61440          4002         0.617   0.329    2   -11.745     1       0.0280
#
#        acousticness  instrumentalness  liveness  ...  \
# 0           0.42100          0.000321    0.4750  ...
# 1           0.10900          0.000070    0.1850  ...
# 2           0.00208          0.341000    0.1690  ...
# 3           0.00947          0.000000    0.1130  ...
# 4           0.13700          0.331000    0.3790  ...
# ...             ...               ...       ...  ...
# 61436       0.04420          0.091100    0.0831  ...
# 61437       0.00697          0.075700    0.2180  ...
# 61438       0.00885          0.271000    0.1330  ...
# 61439       0.00395          0.314000    0.0452  ...
# 61440       0.71600          0.000009    0.0958  ...
#
#                                                     href  is_local  \
# 0      https://api.spotify.com/v1/tracks/3egj44N2tiuW...     False
# 1      https://api.spotify.com/v1/tracks/1WAWbKpQe3XM...     False
# 2      https://api.spotify.com/v1/tracks/1HFIgvDlSCjC...     False
# 3      https://api.spotify.com/v1/tracks/0mEYJIIBcUt2...     False
# 4      https://api.spotify.com/v1/tracks/0vQ5VW753vuq...     False
# ...                                                  ...       ...
# 61436  https://api.spotify.com/v1/tracks/70GM6jmMfyZq...     False
# 61437  https://api.spotify.com/v1/tracks/1hap9S6oZZG0...     False
# 61438  https://api.spotify.com/v1/tracks/4A9dJIJTDQZz...     False
# 61439  https://api.spotify.com/v1/tracks/0jVG6xnJ9w6E...     False
# 61440  https://api.spotify.com/v1/tracks/3JYAnUtZh0uo...     False
#
#                                                name popularity  \
# 0             The Calling - ORIENTAL CRAVINGS Remix          8
# 1      Keeping Score (feat. Paige IV) - Paces Remix         16
# 2             Take My (feat. Rob Taylor) - UZ Remix         11
# 3      Next to You (feat. Savoi) - Yomi Twice Remix          7
# 4                        Pop That - Sub-human Remix          7
# ...                                             ...        ...
# 61436                                        Tattoo         26
# 61437                             Out for the Night         28
# 61438                                       Overdue         26
# 61439                                        Say It         23
# 61440                                  Here to Stay         24
#
#                                              preview_url track_number type_y  \
# 0      https://p.scdn.co/mp3-preview/9fe06ccfa28f6d58...            1  track
# 1      https://p.scdn.co/mp3-preview/d489ef37a269926c...            2  track
# 2      https://p.scdn.co/mp3-preview/1cdf62d1f158ac68...            3  track
# 3      https://p.scdn.co/mp3-preview/cb0178630203d5d8...            4  track
# 4      https://p.scdn.co/mp3-preview/2c60750561e548c1...            5  track
# ...                                                  ...          ...    ...
# 61436  https://p.scdn.co/mp3-preview/70fdfb79463806c4...            8  track
# 61437  https://p.scdn.co/mp3-preview/8b9b4385e713d07e...            9  track
# 61438  https://p.scdn.co/mp3-preview/ab45287017c8db0f...           10  track
# 61439  https://p.scdn.co/mp3-preview/59c8804a7f71a193...           11  track
# 61440  https://p.scdn.co/mp3-preview/9e866a8e078c40c6...           12  track
#
#                                       uri_y  release_date   artist
# 0      spotify:track:3egj44N2tiuW5F2MrqmBjW    2018-02-23  L D R U
# 1      spotify:track:1WAWbKpQe3XMp4b96bjazD    2018-02-23  L D R U
# 2      spotify:track:1HFIgvDlSCjC95Ch6h6gF7    2018-02-23  L D R U
# 3      spotify:track:0mEYJIIBcUt2GH4ftYKJ5Q    2018-02-23  L D R U
# 4      spotify:track:0vQ5VW753vuqUdi4mipjVl    2018-02-23  L D R U
# ...                                     ...           ...      ...
# 61436  spotify:track:70GM6jmMfyZqatFGFdvjE2    2020-05-22    Conro
# 61437  spotify:track:1hap9S6oZZG0uP0h4GoaIu    2020-05-22    Conro
# 61438  spotify:track:4A9dJIJTDQZzkpIUqyUSxe    2020-05-22    Conro
# 61439  spotify:track:0jVG6xnJ9w6EwBqWbvGVfy    2020-05-22    Conro
# 61440  spotify:track:3JYAnUtZh0uoMZrTnHiao2    2020-05-22    Conro
#
# [61441 rows x 38 columns]

# %%
features = ['release_date', 'artist', 'name', 'album', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms_y', 'id']
merged_df = merged_df[features]

# %%
merged_df.shape
# Out:
# (61441, 18)

# %%
merged_df.drop_duplicates(subset = ['name', 'id'], inplace = True)
merged_df
# Out:
# <ipython-input-27-1af34f5715a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df.drop_duplicates(subset = ['name', 'id'], inplace = True)
#       release_date   artist                                          name  \
# 0       2018-02-23  L D R U         The Calling - ORIENTAL CRAVINGS Remix
# 1       2018-02-23  L D R U  Keeping Score (feat. Paige IV) - Paces Remix
# 2       2018-02-23  L D R U         Take My (feat. Rob Taylor) - UZ Remix
# 3       2018-02-23  L D R U  Next to You (feat. Savoi) - Yomi Twice Remix
# 4       2018-02-23  L D R U                    Pop That - Sub-human Remix
# ...            ...      ...                                           ...
# 61436   2020-05-22    Conro                                        Tattoo
# 61437   2020-05-22    Conro                             Out for the Night
# 61438   2020-05-22    Conro                                       Overdue
# 61439   2020-05-22    Conro                                        Say It
# 61440   2020-05-22    Conro                                  Here to Stay
#
#                    album  popularity  danceability  energy  key  loudness  \
# 0      Sizzlar (Remixes)           8         0.531   0.816   10    -4.240
# 1      Sizzlar (Remixes)          16         0.687   0.758    5    -5.285
# 2      Sizzlar (Remixes)          11         0.746   0.944    8    -5.525
# 3      Sizzlar (Remixes)           7         0.433   0.668    6    -7.694
# 4      Sizzlar (Remixes)           7         0.635   0.844    4    -6.086
# ...                  ...         ...           ...     ...  ...       ...
# 61436         Level Days          26         0.663   0.802    1    -7.649
# 61437         Level Days          28         0.740   0.775    9    -7.067
# 61438         Level Days          26         0.761   0.747    1    -8.217
# 61439         Level Days          23         0.806   0.785    0    -6.079
# 61440         Level Days          24         0.617   0.329    2   -11.745
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0         0       0.1020       0.42100          0.000321    0.4750    0.310
# 1         0       0.0564       0.10900          0.000070    0.1850    0.441
# 2         0       0.2460       0.00208          0.341000    0.1690    0.533
# 3         1       0.0443       0.00947          0.000000    0.1130    0.324
# 4         1       0.0970       0.13700          0.331000    0.3790    0.220
# ...     ...          ...           ...               ...       ...      ...
# 61436     0       0.0566       0.04420          0.091100    0.0831    0.390
# 61437     0       0.0567       0.00697          0.075700    0.2180    0.797
# 61438     1       0.0475       0.00885          0.271000    0.1330    0.478
# 61439     1       0.0469       0.00395          0.314000    0.0452    0.258
# 61440     1       0.0280       0.71600          0.000009    0.0958    0.402
#
#          tempo  duration_ms_y                      id
# 0      153.974         180779  3egj44N2tiuW5F2MrqmBjW
# 1       91.911         205000  1WAWbKpQe3XMp4b96bjazD
# 2      140.108         195097  1HFIgvDlSCjC95Ch6h6gF7
# 3      100.008         223764  0mEYJIIBcUt2GH4ftYKJ5Q
# 4       75.031         219200  0vQ5VW753vuqUdi4mipjVl
# ...        ...            ...                     ...
# 61436  163.971         209686  70GM6jmMfyZqatFGFdvjE2
# 61437  107.998         185882  1hap9S6oZZG0uP0h4GoaIu
# 61438  105.029         168880  4A9dJIJTDQZzkpIUqyUSxe
# 61439  115.016         184599  0jVG6xnJ9w6EwBqWbvGVfy
# 61440  135.035         164293  3JYAnUtZh0uoMZrTnHiao2
#
# [41450 rows x 18 columns]

# %%
artist_list = list(set(merged_df['artist']))

# %%
len(artist_list)
# Out:
# 1848

# %%
genres = {}
count = 0
for i in artist_list:
    result = sp.search(i)
    count += 1
    try:
        track = result['tracks']['items'][0]
        artist = sp.artist(track["artists"][0]["external_urls"]["spotify"])
        genres.update({i:artist["genres"]})
    except:
        result = sp.search(i[:8])
        track = result['tracks']['items'][0]
        artist = sp.artist(track["artists"][0]["external_urls"]["spotify"])
        genres.update({i:artist["genres"]})
    if count % 50 == 0:
        time.sleep(np.random.uniform(3, 5))
        print('working on it')
    if count % 500 == 0:
        print(f'{count} artist & genre')
# Out:
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# 500 artist & genre
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# 1000 artist & genre
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it
# 1500 artist & genre
# working on it
# working on it
# working on it
# working on it
# working on it
# working on it

# %%
df = pd.DataFrame(genres.items(), columns=['Name', 'Values'])

# %%
final = pd.merge(merged_df, df,  how='left', left_on='artist', right_on = 'Name')
final.drop(columns = ['Name'], inplace=True)

# %%
final.to_csv('../data/final_merged.csv', index=False)
