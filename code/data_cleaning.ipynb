# %%
import pandas as pd
import ast
import os

# %%
all_files =  os.listdir('../data/')
popular = [f for f in all_files if (f.lower().endswith("popularity.csv"))]
song_feat = [f for f in all_files if (f.lower().endswith("features.csv"))]

# %%
pop_dfs = list()
sf_dfs = list()
for filename in popular:
     dfs = pd.read_csv(f'../data/{filename}')
     pop_dfs.append(dfs)
pop = pd.concat(pop_dfs)

for filename in song_feat:
     sfdfs = pd.read_csv(f'../data/{filename}')
     sf_dfs.append(sfdfs)
feat = pd.concat(sf_dfs)

# %%
pop.head()
# Out:
#    Unnamed: 0                                              album  \
# 0           0  {'album_type': 'album', 'artists': [{'external...
# 1           1  {'album_type': 'album', 'artists': [{'external...
# 2           2  {'album_type': 'album', 'artists': [{'external...
# 3           3  {'album_type': 'album', 'artists': [{'external...
# 4           4  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 1  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 2  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 3  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
# 4  ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT...            1
#
#    duration_ms  explicit              external_ids  \
# 0       270670      True  {'isrc': 'USSM12106858'}
# 1       163508      True  {'isrc': 'USSM12106859'}
# 2        76831      True  {'isrc': 'USSM12106860'}
# 3       316733      True  {'isrc': 'USSM12106861'}
# 4       219813      True  {'isrc': 'USSM12106862'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6G...
# 1  {'spotify': 'https://open.spotify.com/track/3w...
# 2  {'spotify': 'https://open.spotify.com/track/0Z...
# 3  {'spotify': 'https://open.spotify.com/track/7v...
# 4  {'spotify': 'https://open.spotify.com/track/2e...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6G9aDedv5hYa...  6G9aDedv5hYaTgNYDuduqk
# 1  https://api.spotify.com/v1/tracks/3wYMHB6pS2mi...  3wYMHB6pS2miB3Bn9mD36w
# 2  https://api.spotify.com/v1/tracks/0Zt9ySO9K4Br...  0Zt9ySO9K4BrQW7cfFgKFR
# 3  https://api.spotify.com/v1/tracks/7vy76jf6qE0I...  7vy76jf6qE0IvoREJrvZtg
# 4  https://api.spotify.com/v1/tracks/2emAwdap7qy3...  2emAwdap7qy3QEMEeDjQ42
#
#    is_local                                  name  popularity  \
# 0     False                         trademark usa          64
# 1     False                          pink panties          58
# 2     False                            scapegoats          58
# 3     False  range brothers (with Kendrick Lamar)          61
# 4     False                                issues          59
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/67ea2403082fcdea...             1  track
# 1  https://p.scdn.co/mp3-preview/9dba952a9ae41364...             2  track
# 2  https://p.scdn.co/mp3-preview/2272013461d8d2c7...             3  track
# 3  https://p.scdn.co/mp3-preview/6f0c683c94e563dc...             4  track
# 4  https://p.scdn.co/mp3-preview/a2a7575d30dbb170...             5  track
#
#                                     uri
# 0  spotify:track:6G9aDedv5hYaTgNYDuduqk
# 1  spotify:track:3wYMHB6pS2miB3Bn9mD36w
# 2  spotify:track:0Zt9ySO9K4BrQW7cfFgKFR
# 3  spotify:track:7vy76jf6qE0IvoREJrvZtg
# 4  spotify:track:2emAwdap7qy3QEMEeDjQ42

# %%
feat.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.613   0.600   10    -5.621     1       0.2810
# 1           1         0.653   0.547    8    -6.324     1       0.1710
# 2           2         0.585   0.437    4    -7.145     0       0.2230
# 3           3         0.663   0.583   11    -5.789     0       0.2750
# 4           4         0.832   0.541    3    -8.324     0       0.0684
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0       0.10800          0.000002     0.274    0.067  130.732  audio_features
# 1       0.00898          0.000000     0.116    0.248   93.631  audio_features
# 2       0.92300          0.000000     0.154    0.618   80.178  audio_features
# 3       0.00472          0.000000     0.125    0.146  121.678  audio_features
# 4       0.56800          0.001180     0.111    0.233  131.994  audio_features
#
#                        id                                   uri  \
# 0  6G9aDedv5hYaTgNYDuduqk  spotify:track:6G9aDedv5hYaTgNYDuduqk
# 1  3wYMHB6pS2miB3Bn9mD36w  spotify:track:3wYMHB6pS2miB3Bn9mD36w
# 2  0Zt9ySO9K4BrQW7cfFgKFR  spotify:track:0Zt9ySO9K4BrQW7cfFgKFR
# 3  7vy76jf6qE0IvoREJrvZtg  spotify:track:7vy76jf6qE0IvoREJrvZtg
# 4  2emAwdap7qy3QEMEeDjQ42  spotify:track:2emAwdap7qy3QEMEeDjQ42
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6G9aDedv5hYa...
# 1  https://api.spotify.com/v1/tracks/3wYMHB6pS2mi...
# 2  https://api.spotify.com/v1/tracks/0Zt9ySO9K4Br...
# 3  https://api.spotify.com/v1/tracks/7vy76jf6qE0I...
# 4  https://api.spotify.com/v1/tracks/2emAwdap7qy3...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6G9a...       270671
# 1  https://api.spotify.com/v1/audio-analysis/3wYM...       163509
# 2  https://api.spotify.com/v1/audio-analysis/0Zt9...        76832
# 3  https://api.spotify.com/v1/audio-analysis/7vy7...       316733
# 4  https://api.spotify.com/v1/audio-analysis/2emA...       219813
#
#    time_signature
# 0               4
# 1               4
# 2               1
# 3               4
# 4               4

# %%
pop['album'][0]
# Out:
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# 0    {'album_type': 'album', 'artists': [{'external...
# Name: album, dtype: object

# %%
pop['artists'][0]
# Out:
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 0    [{'external_urls': {'spotify': 'https://open.s...
# Name: artists, dtype: object

# %%
dates_list = []
album = []
artist = []
for i in pop['album']:
    temp = ast.literal_eval(i)
    dates_list.append(temp.get('release_date'))
    album.append(temp.get('name'))

for i in pop['artists']:
    res = i.strip('][').split(', ')
    res[3] = res[3].replace("'name': ", "")
    artist.append(res[3].replace("'", ''))


pop['release_date']=dates_list
pop['album'] = album
pop['artist'] = artist

# %%
final = pd.merge(feat, pop, on='id')

# %%
features = ['release_date', 'artist', 'name', 'album', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_ms_y', 'id']
final = final[features]

# %%
final.shape
# Out:
# (20639, 18)

# %%
final.drop_duplicates
final
# Out:
#       release_date         artist                                  name  \
# 0       2021-09-22      Baby Keem                         trademark usa
# 1       2021-09-22      Baby Keem                          pink panties
# 2       2021-09-22      Baby Keem                            scapegoats
# 3       2021-09-22      Baby Keem  range brothers (with Kendrick Lamar)
# 4       2021-09-22      Baby Keem                                issues
# ...            ...            ...                                   ...
# 20634   2003-08-19  Kings of Leon                      Molly's Chambers
# 20635   2003-08-19  Kings of Leon                                Genius
# 20636   2003-08-19  Kings of Leon                                 Dusty
# 20637   2003-08-19  Kings of Leon                 Holy Roller Novocaine
# 20638   2003-08-19  Kings of Leon                          Talihina Sky
#
#                          album  popularity  danceability  energy  key  \
# 0             The Melodic Blue          64         0.613   0.600   10
# 1             The Melodic Blue          58         0.653   0.547    8
# 2             The Melodic Blue          58         0.585   0.437    4
# 3             The Melodic Blue          61         0.663   0.583   11
# 4             The Melodic Blue          59         0.832   0.541    3
# ...                        ...         ...           ...     ...  ...
# 20634  Youth And Young Manhood          63         0.598   0.911   11
# 20635  Youth And Young Manhood          41         0.442   0.830    7
# 20636  Youth And Young Manhood          39         0.661   0.519    9
# 20637  Youth And Young Manhood          49         0.571   0.735   11
# 20638  Youth And Young Manhood          41         0.642   0.522   11
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -5.621     1       0.2810       0.10800          0.000002    0.2740
# 1        -6.324     1       0.1710       0.00898          0.000000    0.1160
# 2        -7.145     0       0.2230       0.92300          0.000000    0.1540
# 3        -5.789     0       0.2750       0.00472          0.000000    0.1250
# 4        -8.324     0       0.0684       0.56800          0.001180    0.1110
# ...         ...   ...          ...           ...               ...       ...
# 20634    -3.970     1       0.0515       0.22200          0.000004    0.2160
# 20635    -5.978     1       0.0478       0.02750          0.000000    0.2180
# 20636    -7.192     1       0.0297       0.16200          0.000000    0.0846
# 20637    -5.632     0       0.0743       0.03290          0.000264    0.2150
# 20638    -5.654     0       0.0261       0.24300          0.000000    0.0915
#
#        valence    tempo  duration_ms_y                      id
# 0        0.067  130.732         270670  6G9aDedv5hYaTgNYDuduqk
# 1        0.248   93.631         163508  3wYMHB6pS2miB3Bn9mD36w
# 2        0.618   80.178          76831  0Zt9ySO9K4BrQW7cfFgKFR
# 3        0.146  121.678         316733  7vy76jf6qE0IvoREJrvZtg
# 4        0.233  131.994         219813  2emAwdap7qy3QEMEeDjQ42
# ...        ...      ...            ...                     ...
# 20634    0.953  146.469         134906  0nCAVzknkzRXRgB6LhRv04
# 20635    0.506  125.554         168840  3iUUve7vVMnS4zHLWpv3mh
# 20636    0.313  105.034         260399  3iYPdrNM4hzxfhmMhb3UoT
# 20637    0.557  106.811         243000  5fv9AxkRVzCwT5XkpYjWvL
# 20638    0.391  114.431         227440  7GWViYkd4fTS3ApKuaTLEB
#
# [20639 rows x 18 columns]
