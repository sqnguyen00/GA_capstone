# %%
import pandas as pd

# %%
pop = pd.read_csv('../data/pop_track_uri.csv')

# %%
pop.head()
# Out:
#    Unnamed: 0                                      external_urls  \
# 0           0  {'spotify': 'https://open.spotify.com/artist/2...
# 1           1  {'spotify': 'https://open.spotify.com/artist/1...
# 2           2  {'spotify': 'https://open.spotify.com/artist/2...
# 3           3  {'spotify': 'https://open.spotify.com/artist/1...
# 4           4  {'spotify': 'https://open.spotify.com/artist/6...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/246dkjvS1zL...  246dkjvS1zLTtiykXe5h60
# 1  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...  1Xyo4u8uXC1ZmMpatF05PJ
# 2  https://api.spotify.com/v1/artists/2tIP7SsRs7v...  2tIP7SsRs7vjIcLrU85W8J
# 3  https://api.spotify.com/v1/artists/1uNFoZAHBGt...  1uNFoZAHBGtllmzznpCI3s
# 4  https://api.spotify.com/v1/artists/6qqNVTkY8uB...  6qqNVTkY8uBg9cP3Jd7DAH
#
#             name    type                                    uri
# ...

# %%
pop = pd.read_csv('../data/pop_track_features.csv')

# %%
pop.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.405   0.646    4    -3.206     0       0.0476
# 1           1         0.617   0.684    0    -3.618     1       0.0439
# 2           2         0.542   0.674    6    -4.169     1       0.2100
# 3           3         0.665   0.741    0    -3.694     1       0.0787
# 4           4         0.632   0.732    6    -3.498     1       0.0920
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0        0.3310          0.000000    0.1030    0.170  130.218  audio_features
# 1        0.0545          0.000000    0.1040    0.295  132.113  audio_features
# 2        0.0588          0.000000    0.0955    0.667   76.388  audio_features
# 3        0.1540          0.000030    0.3450    0.570  144.968  audio_features
# 4        0.1050          0.000012    0.1110    0.317  159.000  audio_features
#
#                        id                                   uri  \
# ...

# %%
pop.shape
# Out:
# (5566, 19)
